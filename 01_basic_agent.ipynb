# %% [markdown]
# # Tutorial 01: Your First Agent - Basic Travel Assistant
#
# ##  Learning Objectives
# By the end of this notebook, you will:
# - Understand what an AI agent is
# - Create your first agent using Microsoft Agent Framework
# - Learn about chat clients and how to configure them
# - Send queries to your agent and get responses
# - Understand agent instructions and how they guide behavior
#
# ##  Key Concepts
#
# ### What is an AI Agent?
# An AI agent uses an LLM to:
# 1. **Process user inputs** - Understand what users are asking
# 2. **Make decisions** - Determine the best way to respond
# 3. **Generate responses** - Provide helpful, contextual answers
#
# ### Components You'll Use
# - **`ChatAgent`** - The main agent class that handles conversations
# - **`OpenAIChatClient`** - Connects your agent to OpenAI's models
# - **Instructions** - System prompts that define your agent's personality and expertise
#
# ---

# %% [markdown]
# ## Step 1: Setup and Installation
#
# First, let's make sure we have the Agent Framework installed and import what we need.

# %%
# Install the Agent Framework (if not already installed)
# !pip install agent-framework
# Out:
# Requirement already satisfied: agent-framework in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (1.0.0b251001)
# Requirement already satisfied: agent-framework-core in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework) (1.0.0b251001)
# Requirement already satisfied: agent-framework-a2a in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework) (1.0.0b251001)
# Requirement already satisfied: agent-framework-azure-ai in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework) (1.0.0b251001)
# Requirement already satisfied: agent-framework-copilotstudio in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework) (1.0.0b251001)
# Requirement already satisfied: agent-framework-mem0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework) (1.0.0b251001)
# Requirement already satisfied: agent-framework-redis in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework) (1.0.0b251001)
# Requirement already satisfied: agent-framework-devui in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework) (1.0.0b251001)
# Requirement already satisfied: a2a-sdk>=0.3.5 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework-a2a->agent-framework) (0.3.7)
# Requirement already satisfied: google-api-core>=1.26.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (2.25.1)
# Requirement already satisfied: httpx-sse>=0.4.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (0.4.1)
# Requirement already satisfied: httpx>=0.28.1 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (0.28.1)
# Requirement already satisfied: protobuf>=5.29.5 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (5.29.5)
# Requirement already satisfied: pydantic>=2.11.3 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (2.11.9)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (1.70.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (2.41.1)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (2.32.5)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (6.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-api-core>=1.26.0->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (0.6.1)
# Requirement already satisfied: anyio in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from httpx>=0.28.1->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from httpx>=0.28.1->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.28.1->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from pydantic>=2.11.3->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from pydantic>=2.11.3->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from pydantic>=2.11.3->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from pydantic>=2.11.3->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (0.4.2)
# Requirement already satisfied: azure-ai-projects>=1.0.0b11 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework-azure-ai->agent-framework) (1.1.0b4)
# Requirement already satisfied: azure-ai-agents==1.2.0b5 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework-azure-ai->agent-framework) (1.2.0b5)
# Requirement already satisfied: aiohttp~=3.8 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework-azure-ai->agent-framework) (3.12.15)
# Requirement already satisfied: isodate>=0.6.1 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from azure-ai-agents==1.2.0b5->agent-framework-azure-ai->agent-framework) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from azure-ai-agents==1.2.0b5->agent-framework-azure-ai->agent-framework) (1.35.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from aiohttp~=3.8->agent-framework-azure-ai->agent-framework) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from aiohttp~=3.8->agent-framework-azure-ai->agent-framework) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from aiohttp~=3.8->agent-framework-azure-ai->agent-framework) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from aiohttp~=3.8->agent-framework-azure-ai->agent-framework) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from aiohttp~=3.8->agent-framework-azure-ai->agent-framework) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from aiohttp~=3.8->agent-framework-azure-ai->agent-framework) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from aiohttp~=3.8->agent-framework-azure-ai->agent-framework) (1.20.1)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from azure-ai-projects>=1.0.0b11->agent-framework-azure-ai->agent-framework) (12.26.0)
# Requirement already satisfied: six>=1.11.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from azure-core>=1.30.0->azure-ai-agents==1.2.0b5->agent-framework-azure-ai->agent-framework) (1.17.0)
# Requirement already satisfied: cryptography>=2.1.4 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from azure-storage-blob>=12.15.0->azure-ai-projects>=1.0.0b11->agent-framework-azure-ai->agent-framework) (46.0.2)
# Requirement already satisfied: cffi>=2.0.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from cryptography>=2.1.4->azure-storage-blob>=12.15.0->azure-ai-projects>=1.0.0b11->agent-framework-azure-ai->agent-framework) (2.0.0)
# Requirement already satisfied: pycparser in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=2.1.4->azure-storage-blob>=12.15.0->azure-ai-projects>=1.0.0b11->agent-framework-azure-ai->agent-framework) (2.23)
# Requirement already satisfied: microsoft-agents-copilotstudio-client>=0.3.1 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework-copilotstudio->agent-framework) (0.3.2)
# Requirement already satisfied: microsoft-agents-hosting-core==0.3.2 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from microsoft-agents-copilotstudio-client>=0.3.1->agent-framework-copilotstudio->agent-framework) (0.3.2)
# Requirement already satisfied: microsoft-agents-activity==0.3.2 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from microsoft-agents-hosting-core==0.3.2->microsoft-agents-copilotstudio-client>=0.3.1->agent-framework-copilotstudio->agent-framework) (0.3.2)
# Requirement already satisfied: pyjwt>=2.10.1 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from microsoft-agents-hosting-core==0.3.2->microsoft-agents-copilotstudio-client>=0.3.1->agent-framework-copilotstudio->agent-framework) (2.10.1)
# Requirement already satisfied: python-dotenv>=1.1.1 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from microsoft-agents-hosting-core==0.3.2->microsoft-agents-copilotstudio-client>=0.3.1->agent-framework-copilotstudio->agent-framework) (1.1.1)
# Requirement already satisfied: openai>=1.99.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework-core->agent-framework) (1.109.1)
# Requirement already satisfied: pydantic-settings<3,>=2 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework-core->agent-framework) (2.11.0)
# Requirement already satisfied: opentelemetry-api>=1.24 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework-core->agent-framework) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.24 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework-core->agent-framework) (1.37.0)
# Requirement already satisfied: mcp>=1.13 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from mcp[ws]>=1.13->agent-framework-core->agent-framework) (1.15.0)
# Requirement already satisfied: azure-monitor-opentelemetry>=1.7.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework-core->agent-framework) (1.8.1)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter>=1.0.0b41 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework-core->agent-framework) (1.0.0b42)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.36.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework-core->agent-framework) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions-ai>=0.4.13 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework-core->agent-framework) (0.4.13)
# Requirement already satisfied: aiofiles>=24.1.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework-core->agent-framework) (24.1.0)
# Requirement already satisfied: azure-identity<2,>=1 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework-core->agent-framework) (1.25.0)
# Requirement already satisfied: msal>=1.30.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from azure-identity<2,>=1->agent-framework-core->agent-framework) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from azure-identity<2,>=1->agent-framework-core->agent-framework) (1.3.1)
# Requirement already satisfied: azure-core-tracing-opentelemetry~=1.0.0b11 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework) (1.0.0b12)
# Requirement already satisfied: opentelemetry-instrumentation-django~=0.57b0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi~=0.57b0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-flask~=0.57b0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-psycopg2~=0.57b0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-requests~=0.57b0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib~=0.57b0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib3~=0.57b0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework) (0.58b0)
# Requirement already satisfied: opentelemetry-resource-detector-azure~=0.1.5 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework) (0.1.5)
# Requirement already satisfied: fixedint==0.1.6 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core->agent-framework) (0.1.6)
# Requirement already satisfied: msrest>=0.6.10 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core->agent-framework) (0.7.1)
# Requirement already satisfied: psutil<8,>=5.9 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core->agent-framework) (7.1.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from opentelemetry-api>=1.24->agent-framework-core->agent-framework) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.24->agent-framework-core->agent-framework) (3.23.0)
# Requirement already satisfied: opentelemetry-instrumentation-wsgi==0.58b0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework) (0.58b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.58b0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework) (0.58b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework) (0.58b0)
# Requirement already satisfied: opentelemetry-util-http==0.58b0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework) (0.58b0)
# Requirement already satisfied: packaging>=18.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework) (25.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-django~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework) (1.17.3)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.58b0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework) (0.58b0)
# Requirement already satisfied: asgiref~=3.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.58b0->opentelemetry-instrumentation-fastapi~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework) (3.9.2)
# Requirement already satisfied: opentelemetry-instrumentation-dbapi==0.58b0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-psycopg2~=0.57b0->azure-monitor-opentelemetry>=1.7.0->agent-framework-core->agent-framework) (0.58b0)
# Requirement already satisfied: jsonschema>=4.20.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework) (4.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework) (0.48.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework) (0.37.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from anyio->httpx>=0.28.1->a2a-sdk>=0.3.5->agent-framework-a2a->agent-framework) (1.3.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework) (0.27.1)
# Requirement already satisfied: websockets>=15.0.1 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from mcp[ws]>=1.13->agent-framework-core->agent-framework) (15.0.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core->agent-framework) (2.0.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from openai>=1.99.0->agent-framework-core->agent-framework) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from openai>=1.99.0->agent-framework-core->agent-framework) (0.11.0)
# Requirement already satisfied: tqdm>4 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from openai>=1.99.0->agent-framework-core->agent-framework) (4.67.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework) (1.75.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.36.0->agent-framework-core->agent-framework) (1.37.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-monitor-opentelemetry-exporter>=1.0.0b41->agent-framework-core->agent-framework) (3.3.1)
# Requirement already satisfied: click>=7.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp>=1.13->mcp[ws]>=1.13->agent-framework-core->agent-framework) (8.3.0)
# Requirement already satisfied: fastapi>=0.104.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework-devui->agent-framework) (0.118.0)
# Requirement already satisfied: httptools>=0.6.3 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework) (0.6.4)
# Requirement already satisfied: pyyaml>=5.1 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework) (6.0.3)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.24.0->agent-framework-devui->agent-framework) (1.1.0)
# Requirement already satisfied: mem0ai>=0.1.117 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework-mem0->agent-framework) (0.1.118)
# Requirement already satisfied: posthog>=3.5.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (6.7.6)
# Requirement already satisfied: pytz>=2024.1 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (2025.2)
# Requirement already satisfied: qdrant-client>=1.9.1 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (1.15.1)
# Requirement already satisfied: sqlalchemy>=2.0.31 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (2.0.43)
# Requirement already satisfied: python-dateutil>=2.2 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from posthog>=3.5.0->mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from posthog>=3.5.0->mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (2.2.1)
# Requirement already satisfied: numpy>=1.26 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (2.3.3)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (3.2.0)
# Requirement already satisfied: h2<5,>=3 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai>=0.1.117->agent-framework-mem0->agent-framework) (4.1.0)
# Requirement already satisfied: redis>=6.4.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework-redis->agent-framework) (6.4.0)
# Requirement already satisfied: redisvl>=0.8.2 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from agent-framework-redis->agent-framework) (0.9.1)
# Requirement already satisfied: jsonpath-ng>=1.5.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework) (1.7.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.4.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework) (0.5.3)
# Requirement already satisfied: python-ulid>=3.0.0 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework) (3.1.0)
# Requirement already satisfied: tenacity>=8.2.2 in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from redisvl>=0.8.2->agent-framework-redis->agent-framework) (9.1.2)
# Requirement already satisfied: ply in /Users/gk/AIFoundryProjects/my-ai-agent/venv/lib/python3.12/site-packages (from jsonpath-ng>=1.5.0->redisvl>=0.8.2->agent-framework-redis->agent-framework) (3.11)

# %%
# Import required modules
import asyncio
from agent_framework import ChatAgent
from agent_framework.openai import OpenAIChatClient
from agent_framework.azure import AzureOpenAIChatClient


print("✅ Imports successful!")
# Out:
# ✅ Imports successful!

# %% [markdown]
# ## Step 2: Configure Your API Key
#
# The agent needs access to an LLM. We'll use OpenAI, but you can also use Azure OpenAI or other providers.
#
#
#  CONFIGURATION - Azure OpenAI credentials from environment variables
#
#  These should be set in your .env file:
#  - AZURE_OPENAI_ENDPOINT: Your Azure OpenAI endpoint URL
#  - AZURE_OPENAI_API_KEY: Your Azure OpenAI API key
#  - MODEL_DEPLOYMENT_NAME: The name of your deployed model (e.g., gpt-4, gpt-35-turbo)

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()


AZURE_OPENAI_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
AZURE_OPENAI_API_KEY = os.getenv("AZURE_OPENAI_API_KEY")
MODEL_DEPLOYMENT_NAME = os.getenv("MODEL_DEPLOYMENT_NAME")

# %% [markdown]
# ## Step 3: Create Your First Agent
#
# Let's create a simple Travel Assistant agent. Notice three key components:
# 1. **Chat Client** - Connects to OpenAI
# 2. **Instructions** - Tells the agent what it is and what it should do
# 3. **Name** - Optional, but helpful for debugging and multi-agent scenarios

# %%
# Create a chat client that connects to OpenAI
chat_client = AzureOpenAIChatClient(
    endpoint=AZURE_OPENAI_ENDPOINT,
    api_key=AZURE_OPENAI_API_KEY,
    deployment_name=MODEL_DEPLOYMENT_NAME
)

# Create the agent
travel_agent = ChatAgent(
    chat_client=chat_client,
    name="TravelAssistant",
    instructions="""
    You are a friendly and knowledgeable travel assistant. Your role is to help users
    plan trips, answer questions about destinations, and provide travel advice.
    
    Guidelines:
    - Be enthusiastic and encouraging about travel
    - Provide specific, actionable recommendations
    - Consider factors like budget, time of year, and traveler interests
    - If you don't know something, be honest about it
    """
)

print(" Travel Assistant agent created successfully!")
# Out:
# ✅ Travel Assistant agent created successfully!

# %% [markdown]
# ## Step 4: Have Your First Conversation
#
# Now let's interact with our agent! We'll use the `run()` method to send queries.

# %%
# Simple query
query = "What are the best destinations for a beach vacation in Europe?"

print(f"User: {query}\n")

# Run the agent (await because it's async)
response = await travel_agent.run(query)

print(f"Agent: {response}")
# Out:
# User: What are the best destinations for a beach vacation in Europe?
#
# Agent: Absolutely, European beaches offer a wonderful mix of sun, sand, culture, and relaxation! Here are some of the best beach destinations in Europe, catering to different budgets and travel styles:
#
# ---
#
# ### 1. Algarve, Portugal
# **Why go?** Dramatic cliffs, golden beaches, picturesque towns, and delicious seafood.
# **Best time:** May–September
# **Top spots:** Lagos, Praia da Marinha, Albufeira
# **Budget tips:** Plenty of affordable guesthouses and local restaurants.
#
# ---
#
# ### 2. Greek Islands (Santorini, Mykonos, Crete, Zakynthos)
# **Why go?** Crystal-clear waters, postcard-perfect seaside villages, and unique beach experiences (like black sand on Santorini).
# **Best time:** Late May–October
# **Top spots:** Elafonissi (Crete), Navagio (Zakynthos), Psarou (Mykonos)
# **Budget tips:** Opt for Crete or Naxos for better value compared to Santorini/Mykonos.
#
# ---
#
# ### 3. Amalfi Coast & Capri, Italy
# **Why go?** Stunning cliffs, vibrant towns, chic beach clubs, delicious Italian cuisine.
# **Best time:** Late May–September
# **Top spots:** Positano, Ravello, Capri’s Marina Piccola
# **Budget tips:** Stay in towns like Minori or Praiano for lower prices.
#
# ---
#
# ### 4. Costa Brava, Spain
# **Why go?** Rugged coastline, charming fishing villages, and lots of hidden coves.
# **Best time:** June–September
# **Top spots:** Tossa de Mar, Calella de Palafrugell, Lloret de Mar
# **Budget tips:** Regional trains make getting around affordable.
#
# ---
#
# ### 5. French Riviera (Côte d'Azur)
# **Why go?** Glamorous beaches, lively cities, and historic charm.
# **Best time:** May–September
# **Top spots:** Nice, Cannes, Antibes, Saint-Tropez
# **Budget tips:** Consider nearby Menton or Villefranche-sur-Mer for budget-friendly stays.
#
# ---
#
# ### 6. Dubrovnik & Croatian Islands
# **Why go?** Gorgeous Adriatic coastline, medieval towns, and secluded pebble/beach areas.
# **Best time:** June–September
# **Top spots:** Lokrum Island, Mljet, Hvar, Korčula
# **Budget tips:** Croatia offers great value compared to Western Europe.
#
# ---
#
# ### 7. Mallorca & Ibiza, Spain (Balearic Islands)
# **Why go?** Turquoise waters, sandy beaches, vibrant nightlife (Ibiza), and scenic coves.
# **Best time:** May–October
# **Top spots:** Cala d’Or, Cala Comte (Ibiza), Es Trenc (Mallorca)
# **Budget tips:** Mallorca generally more affordable than Ibiza.
#
# ---
#
# ## Tips for Planning Your Trip
# - **Book early for best prices in peak season (June-August).**
# - **Shoulder season (May–early June, September–October) offers milder weather and better deals.**
# - **Consider flights or ferries between islands (especially Greece and Croatia).**
# - **Check local festivals for a unique experience!**
#
# If you have a preferred country, type of beach (quiet vs bustling), or budget, I can recommend even more specific spots! Where would you like to go?

# %% [markdown]
# ## Step 5: Try More Queries
#
# Let's ask different types of questions to see how our agent responds.

# %%
# Ask about a specific destination
query = "Tell me about visiting Tokyo. What should I see?"

print(f"User: {query}\n")
response = await travel_agent.run(query)
print(f"Agent: {response}")
# Out:
# User: Tell me about visiting Tokyo. What should I see?
#
# Agent: Tokyo is a fantastic city—truly one of the world’s most exciting destinations! Whether you love art, food, shopping, or exploring unique neighborhoods, there’s something for everyone. Here are some must-see spots and tips for a great trip:
#
# ### Must-See Neighborhoods & Sights
#
# **1. Shibuya**
# - Famous for the iconic Shibuya Crossing—the world’s busiest pedestrian crossing.
# - Vibrant shopping and dining, the Hachiko statue, and nightlife.
#
# **2. Shinjuku**
# - Explore Shinjuku Gyoen National Garden (gorgeous, especially during cherry blossom season).
# - Check out the views from the Tokyo Metropolitan Government Building (free observation decks).
# - Enjoy Omoide Yokocho and Golden Gai for atmospheric bars and local eats.
#
# **3. Asakusa**
# - Home to Senso-ji, Tokyo’s oldest temple. The surrounding streets are full of traditional shops and street foods.
# - Take a stroll along the Sumida River, or hop on a river cruise!
#
# **4. Akihabara**
# - Heaven for fans of anime, manga, and electronics. Visit themed cafés and explore the vibrant gaming culture.
#
# **5. Harajuku**
# - Don’t miss Takeshita Street for crazy fashions and fun snacks.
# - Stroll through serene Meiji Shrine and its beautiful park.
#
# **6. Ginza**
# - Tokyo’s upscale shopping district; great for window-shopping and chic cafés.
# - Explore art galleries and department stores (some have rooftop gardens).
#
# ### Unique Experiences
#
# - **Tsukiji Outer Market:** Sample fresh sushi, seafood, and street food.
# - **TeamLab Planets/Toyosu:** Experience digital art in immersive installations.
# - **Day Trip to Odaiba:** Entertainment complex with shopping, museums, and waterfront views.
# - **Sumo Wrestling:** If your visit lines up with a tournament, it’s an amazing cultural event. Otherwise, some sumo stables allow tourists to observe morning practice.
#
# ### Food & Drink
#
# - Try ramen, tempura, yakiniku (grilled meat), and izakaya-style dining.
# - Don’t be shy about venturing into small, local restaurants—they’re often delicious and affordable!
#
# ### Tips
#
# - **Transport:** Get a Suica or PASMO card for easy subway travel.
# - **Season:** Spring (cherry blossoms in March/April) and autumn (October/November) offer pleasant weather.
# - **Budget:** Tokyo ranges from budget hostels to luxury hotels—there’s something for every price point. Street food and convenience store meals are surprisingly good for tight budgets!
#
# What are you most interested in—food, culture, architecture, shopping, or something else? Let me know, and I can tailor recommendations to fit your travel style!

# %%
# Ask for specific recommendations
query = "I have 5 days and a $2000 budget. Where should I go from New York?"

print(f"User: {query}\n")
response = await travel_agent.run(query)
print(f"Agent: {response}")
# Out:
# User: I have 5 days and a $2000 budget. Where should I go from New York?
#
# Agent: That’s awesome! With 5 days and a $2,000 budget, you have some fantastic options for a memorable trip from New York. Here are several ideas based on different interests:
#
# ---
#
# ### 1. Montreal, Canada
# **Why Go**: It's close, offers a mix of European charm and North American energy, and is great for food, culture, and festivals.
#
# - **Travel**: Take an Amtrak train or fly (flights are usually under 2 hours; round-trip can often be found for $250–$400).
# - **Accommodation**: Boutique hotels or Airbnbs ($150–$200/night).
# - **Must-Do**: Explore Old Montreal, visit the Jean-Talon Market, try local cafes and poutine, climb Mont Royal.
# - **Tip**: Bring your passport!
#
# ---
#
# ### 2. Charleston, South Carolina
# **Why Go**: Gorgeous historic streets, excellent food, and southern charm.
#
# - **Travel**: Direct flights (~2.5 hours; round-trip $200–$350).
# - **Accommodation**: Historic inns or downtown hotels ($180–$220/night).
# - **Must-Do**: Walk the Waterfront Park, enjoy low country cuisine, take a carriage tour, visit nearby beaches.
# ---
#
# ### 3. Puerto Rico
# **Why Go**: Tropical vibes, no passport required, beautiful beaches, and vibrant culture.
#
# - **Travel**: Direct flights to San Juan (3.5–4 hours; often $200–$350 round-trip).
# - **Accommodation**: Guesthouses, boutique hotels in Old San Juan ($120–$180/night).
# - **Must-Do**: Explore Old San Juan, visit El Yunque rainforest, relax on Condado Beach.
# - **Tip**: Car rentals are cheap if you want to see more of the island.
#
# ---
#
# ### 4. National Parks Adventure (Domestic Road Trip)
# **Why Go**: Outdoor scenery, hiking, flexibility with budget.
#
# - **Options**: Acadia (Maine), Shenandoah (Virginia), Great Smoky Mountains (Tennessee/North Carolina).
# - **Travel**: Rent a car ($40–$70/day), gas, and park fees.
# - **Accommodation**: Campgrounds or budget motels ($60–$120/night).
# - **Must-Do**: Scenic drives, day hikes, local eats.
#
# ---
#
# ### 5. Mexico City, Mexico
# **Why Go**: Dynamic city, amazing food and art, affordable cost of living.
#
# - **Travel**: Direct flight (~5 hours; often $400–$600 round-trip).
# - **Accommodation**: Trendy hostels, boutique hotels ($80–$130/night).
# - **Must-Do**: Explore Centro Histórico, Frida Kahlo Museum, markets, day trip to Teotihuacán pyramids.
# - **Tip**: Your budget goes far thanks to great exchange rates.
#
# ---
#
# ### Travel Tips
# - Try booking flights about 6–8 weeks in advance for best deals.
# - Consider package deals (flight + hotel) for savings.
# - Travel insurance is a good idea, especially for international trips.
# - If you want something more relaxing, consider spa destinations or beach resorts.
#
# ---
#
# **Is there a particular vibe, climate, or activity you want for your trip—like adventure, food, relaxation, or culture? Let me know and I’ll tailor my recommendation even more specifically to YOU!**

# %%
# Ask for travel tips
query = "What should I pack for a winter trip to Iceland?"

print(f"User: {query}\n")
response = await travel_agent.run(query)
print(f"Agent: {response}")
# Out:
# User: What should I pack for a winter trip to Iceland?
#
# Agent: How exciting—a winter trip to Iceland! Iceland’s winter weather can be unpredictable, with snow, wind, and chilly temperatures, but a little planning can make your adventure comfortable and magical. Here’s a detailed packing list to help you:
#
# ### **Clothing**
# - **Thermal base layers:** Pack moisture-wicking long-sleeve shirts and leggings; Merino wool is great!
# - **Warm sweaters:** Wool or fleece works well as mid-layers.
# - **Waterproof and windproof outerwear:** A good insulated jacket and waterproof pants are essential for staying dry and warm.
# - **Sturdy waterproof boots:** Snow and ice are common; boots with good grip are a must.
# - **Thick socks:** Wool socks keep feet warm and dry.
# - **Gloves/mittens:** Consider waterproof gloves for extra warmth.
# - **Warm hat:** Covers your ears!
# - **Scarf or neck gaiter:** Essential to protect against icy winds.
# - **Swimsuit:** For hot springs like the Blue Lagoon or local geothermal pools!
#
# ### **Accessories**
# - **Sunglasses:** The snow reflects sunlight, which can be surprisingly bright.
# - **Reusable water bottle:** Tap water is fresh and safe.
# - **Power bank:** Essential since cold weather can drain batteries faster.
# - **Travel adapter:** Iceland uses the standard European plug (Type F).
# - **Camera:** For northern lights, waterfalls, and unique landscapes.
# - **Daypack:** Useful for day trips and excursions.
#
# ### **Toiletries & Extras**
# - **Moisturizer & lip balm:** Cold, dry air can be tough on skin.
# - **Medications:** Especially anything you take regularly—access to certain meds may be limited.
# - **First aid kit:** Always good to have for any minor cuts/scrapes.
#
# ### **Special Considerations**
# - **Hand/foot warmers:** Great for long outdoor activities.
# - **Ice grips for boots:** Useful if you plan to walk in icy areas.
# - **Layers, layers, layers:** The key to comfort is wearing multiple layers you can adjust throughout the day.
#
# **Tip:** Weather changes quickly—always check the forecast, and pack an extra layer just in case!
#
# If you let me know your planned activities (Northern Lights chasing, glacier hikes, city sightseeing), I can tailor this list even more. Have a fantastic time—winter in Iceland is truly magical!

# %% [markdown]
# ## 🔍 Understanding What Just Happened
#
# Let's break down the flow:
#
# ```
# 1. User Query → 2. ChatAgent → 3. AzureOpenAIChatClient → 4. AzureOpenAI API (LLM)
#                                                             ↓
# 8. Display ← 7. ChatAgent ← 6. AzureOpenAIChatClient ← 5. Response
# ```
#
# **Key Points:**
# - Each `run()` call is **independent** - the agent doesn't remember previous conversations (yet!)
# - The **instructions** guide how the agent responds to ALL queries
# - The agent uses the LLM's knowledge up to its training cutoff date

# %% [markdown]
# ## 🎨 Experiment: Change the Instructions
#
# Let's see how instructions affect behavior. Create a more casual version of the agent.

# %%
# Create a more casual travel buddy
casual_agent = ChatAgent(
    chat_client=chat_client,
    name="CasualTravelBuddy",
    instructions="""
    You're a chill travel buddy who's been everywhere and loves sharing stories.
    Keep it casual, use emojis, and give honest opinions. Don't be too formal!
    """
)

query = "What are the best destinations for a beach vacation in Europe?"

print(f"User: {query}\n")
response = await casual_agent.run(query)
print(f"Casual Agent: {response}")
# Out:
# User: What are the best destinations for a beach vacation in Europe?
#
# Casual Agent: Oh man, Europe is packed with epic beach spots! 😎🌊 Depends what vibe you're after, but here are a few faves:
#
# **1. Algarve, Portugal**
# Golden cliffs, secret coves, and just laid-back vibes. Surfers, foodies, and sun-lovers all fit in here. Lagos is super fun, but there are quieter spots too!
#
# **2. Greek Islands (Santorini, Mykonos, Crete...)**
# Crystal clear water, blue domes, killer sunsets. Santorini is romantic, Mykonos has parties, Crete’s got wild beaches (Elafonissi is dreamy).
#
# **3. Amalfi Coast, Italy**
# Okay, technically beaches are small (sometimes just pebbles), but the views? Unreal. Positano is pure Instagram goals. Try Sorrento for fewer crowds.
#
# **4. Costa Brava, Spain**
# You get cliffside villages, turquoise bays, and some killer seafood. Tossa de Mar is a must for chill beach vibes.
#
# **5. French Riviera (Nice, Antibes, St. Tropez...)**
# Glitz & glamour mixed with med beaches. More pricey but sometimes you just gotta splurge. Nice beaches are pebbly, but the water is 💙.
#
# **6. Croatia (Hvar, Dubrovnik, Split...)**
# Adriatic Sea’s even warmer than the Med! Hvar is party central, but tiny islands like Vis feel like secret hideouts.
#
# **Personal pick:**
# If you want something low-key and affordable, the south of Albania (like Ksamil) is surprisingly gorgeous and not packed yet!
#
# What’s your beach style—crazy parties, quiet coves, or family vibe? I can recommend more tailored spots! 🚀

# %% [markdown]
# Notice how the **same query** gets a different tone and style based on instructions!

# %% [markdown]
# ## 💡 Key Takeaways
#
# 1. **Creating an agent is simple**: Just provide a chat client and instructions
# 2. **Instructions are powerful**: They define personality, expertise, and behavior
# 3. **Agents are stateless by default**: Each `run()` is independent (we'll fix this in Tutorial 03)
# 4. **The framework abstracts complexity**: You don't deal with API calls, token management, etc.
#
# ## 🚧 Current Limitations
#
# Our agent is basic and has limitations:
# - ❌ Can't call external APIs (weather, flights, etc.)
# - ❌ Doesn't remember previous messages
# - ❌ Can't verify real-time information
# - ❌ Limited to the LLM's training data
#
# **In the next tutorial**, we'll add **Tools** to let the agent call functions and get real-time data!
#
# ---

# %% [markdown]
# ## 📚 What's Next?
#
# In **Tutorial 02: Agent with Tools**, you'll learn to:
# - Add function calling capabilities
# - Create tools for weather checking and currency conversion
# - Let the agent decide when to use tools
# - Handle tool errors and responses
#
# **Ready?** → Open `02_agent_with_tools.ipynb`
